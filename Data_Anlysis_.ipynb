# %% [markdown]
# #Functions
# 1. what is the deffernce between funtion ad metho in Paython ?
# - Python, the fundamental difference between a function and a method is that a method is a function that is associated with an object or a class, meaning it is defined inside a class, while a function is a standalone block of code that is not tied to a specific object or class instance
#
# 2. What is python
# - Python is a popular, high-level, general-purpose programming language known for its simple, readable syntax that resembles English

# %%
# What is Python
...
Python is a popular, high-level, general-purpose programming language known for its simple, readable syntax that resembles English
...
this is answer
...
